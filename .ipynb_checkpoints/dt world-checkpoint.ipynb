# %%
import pandas as pd   
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
from pickle import dump
from sklearn.model_selection import train_test_split

#metrics
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_validate

#cross validation
from sklearn.model_selection  import cross_val_score 
from sklearn.metrics import accuracy_score, classification_report

#ML models
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble  import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
#default theme and settings
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)
pd.set_option('display.max_columns', None)

#warning handle
import warnings
warnings.filterwarnings("ignore")

# %%
world_df = pd.read_csv('Countries.csv',index_col=0)
world_df.head()
# Out:
#                 Birth Rate  Business Tax Rate  log10_CO2 Emissions  \
# Country
# Afghanistan       0.041187          37.790852             3.448751
# Albania           0.013827          41.728826             3.817068
# Algeria           0.022987          47.810756             5.041422
# American Samoa    0.019530          36.098327             2.615035
# Andorra           0.010333          39.574833             2.726592
#
#                 Days to Start Business  Ease of Business  log10_Energy Usage  \
# Country
# Afghanistan                  10.615147        173.820524            3.583827
# Albania                      20.217653        125.172350            3.418761
# Algeria                      25.228467        141.974156            4.560178
# American Samoa               17.000000         91.116532            1.486228
# Andorra                      23.195551         73.849854            3.223342
#
#                 log10_GDP  Health Exp % GDP  log10_Health Exp/Capita  \
# ...

# %%
x = world_df.iloc[:,:-2].round(3)

# %%
x.keys()
# Out:
# Index(['Birth Rate', 'Business Tax Rate', 'log10_CO2 Emissions',
#        'Days to Start Business', 'Ease of Business', 'log10_Energy Usage',
#        'log10_GDP', 'Health Exp % GDP', 'log10_Health Exp/Capita',
#        'Hours to do Tax', 'Infant Mortality Rate', 'Internet Usage',
#        'Lending Interest', 'Life Expectancy Female', 'Life Expectancy Male',
#        'Mobile Phone Usage', 'log10_Population Total', 'Population Urban',
#        'log10_Tourism Inbound', 'log10_Tourism Outbound'],
#       dtype='object')

# %%
y = world_df['cluster_label']

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier()

# %%
model = dc.fit(x,y)

# %%
x
# Out:
#                                                     Birth Rate  \
# Country
# Afghanistan                                              0.041
# Albania                                                  0.014
# Algeria                                                  0.023
# American Samoa                                           0.020
# Andorra                                                  0.010
# Angola                                                   0.048
# Antigua and Barbuda                                      0.018
# Argentina                                                0.017
# Armenia                                                  0.014
# Aruba                                                    0.012
# Australia                                                0.014
# Austria                                                  0.009
# Azerbaijan                                               0.017
# Bahamas                                                  0.015
# ...

# %%
y
# Out:
# Country
# Afghanistan                                             1
# Albania                                                 0
# Algeria                                                 0
# American Samoa                                          3
# Andorra                                                 3
# Angola                                                  1
# Antigua and Barbuda                                     3
# Argentina                                               0
# Armenia                                                 0
# Aruba                                                   3
# Australia                                               2
# Austria                                                 2
# Azerbaijan                                              0
# Bahamas                                                 3
# Bahrain                                                 2
# Bangladesh                                              0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20,shuffle=True)

# %%
x_train
# Out:
#                                                     Birth Rate  \
# Country
# Kiribati                                                 0.024
# New Caledonia                                            0.017
# Azerbaijan                                               0.017
# Djibouti                                                 0.029
# Saint Vincent and the Grenadines                         0.018
# Egypt                                                    0.024
# Senegal                                                  0.039
# Greece                                                   0.010
# Moldova, Republic of                                     0.012
# Cuba                                                     0.011
# Netherlands                                              0.011
# Kyrgyzstan                                               0.024
# Morocco                                                  0.021
# Burkina Faso                                             0.044
# ...

# %%
y_train
# Out:
# Country
# Kiribati                                                3
# New Caledonia                                           3
# Azerbaijan                                              0
# Djibouti                                                1
# Saint Vincent and the Grenadines                        3
# Egypt                                                   0
# Senegal                                                 1
# Greece                                                  2
# Moldova, Republic of                                    0
# Cuba                                                    0
# Netherlands                                             2
# Kyrgyzstan                                              0
# Morocco                                                 0
# Burkina Faso                                            1
# Turkmenistan                                            1
# Puerto Rico                                             2
# ...

# %% [markdown]
# # Classification models

# %% [markdown]
# # Support vector Classification

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[13  1  0  0]
#  [ 1 17  0  0]
#  [ 1  0 15  0]
#  [ 0  1  3 11]]

# %%
acc2 = accuracy_score(y_test, y_pred)
print(f"Accuracy score: {acc2}")
# Out:
# Accuracy score: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        14
#            1       0.89      0.94      0.92        18
#            2       0.83      0.94      0.88        16
#            3       1.00      0.73      0.85        15
#
#     accuracy                           0.89        63
#    macro avg       0.90      0.89      0.89        63
# weighted avg       0.90      0.89      0.89        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[14  0  0  0]
#  [ 0 18  0  0]
#  [ 3  0 13  0]
#  [ 1  0  0 14]]

# %%
print(f"Random Forest Classification accuracy: {acc2}")
# Out:
# Random Forest Classification accuracy: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        14
#            1       1.00      1.00      1.00        18
#            2       1.00      0.81      0.90        16
#            3       1.00      0.93      0.97        15
#
#     accuracy                           0.94        63
#    macro avg       0.94      0.94      0.93        63
# weighted avg       0.95      0.94      0.94        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

classifier =GradientBoostingClassifier()
classifier.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[13  1  0  0]
#  [ 1 17  0  0]
#  [ 2  0 13  1]
#  [ 2  1  1 11]]

# %%
print(f"By XG Boost classifier Acc: {acc2}")
# Out:
# By XG Boost classifier Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81        14
#            1       0.89      0.94      0.92        18
#            2       0.93      0.81      0.87        16
#            3       0.92      0.73      0.81        15
#
#     accuracy                           0.86        63
#    macro avg       0.87      0.85      0.85        63
# weighted avg       0.87      0.86      0.86        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

classifier =AdaBoostClassifier()
classifier.fit(x_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[14  0  0  0]
#  [ 5 13  0  0]
#  [14  0  1  1]
#  [ 1  3  0 11]]

# %%
print(f"By Ada Boost classifier Acc: {acc2}")
# Out:
# By Ada Boost classifier Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        14
#            1       0.81      0.72      0.76        18
#            2       1.00      0.06      0.12        16
#            3       0.92      0.73      0.81        15
#
#     accuracy                           0.62        63
#    macro avg       0.79      0.63      0.57        63
# weighted avg       0.80      0.62      0.57        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

classifier =BaggingClassifier()
classifier.fit(x_train, y_train)
# Out:
# BaggingClassifier()

# %%
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[12  2  0  0]
#  [ 1 17  0  0]
#  [ 2  0 14  0]
#  [ 1  0  2 12]]

# %%
print(f"By Baggingclassifier Acc: {acc2}")
# Out:
# By Baggingclassifier Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        14
#            1       0.89      0.94      0.92        18
#            2       0.88      0.88      0.88        16
#            3       1.00      0.80      0.89        15
#
#     accuracy                           0.87        63
#    macro avg       0.88      0.87      0.87        63
# weighted avg       0.88      0.87      0.87        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

logreg =LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[13  1  0  0]
#  [ 1 17  0  0]
#  [ 1  0 14  1]
#  [ 1  1  2 11]]

# %%
print(f"By LogisticRegression Acc: {acc2}")
# Out:
# By LogisticRegression Acc: 0.8888888888888888

# %%
y_pred_test = logreg.predict(x_test)

y_pred_test
# Out:
# array([0, 1, 3, 3, 3, 1, 2, 0, 2, 0, 2, 0, 3, 3, 1, 2, 0, 0, 2, 0, 1, 1,
#        0, 1, 1, 2, 0, 1, 0, 2, 1, 3, 0, 3, 0, 0, 0, 3, 1, 1, 2, 1, 0, 2,
#        1, 2, 1, 1, 1, 3, 2, 2, 1, 3, 2, 1, 3, 0, 3, 2, 2, 2, 1],
#       dtype=int64)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.89      0.94      0.92        18
#            2       0.88      0.88      0.88        16
#            3       0.92      0.73      0.81        15
#
#     accuracy                           0.87        63
#    macro avg       0.87      0.87      0.87        63
# weighted avg       0.88      0.87      0.87        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # Naive Bayes classifier

# %%
# train a Gaussian Naive Bayes classifier on the training set
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_train)

y_pred
# Out:
# array([3, 3, 0, 1, 3, 0, 1, 2, 0, 0, 2, 0, 0, 1, 1, 2, 1, 2, 3, 1, 2, 1,
#        2, 0, 1, 1, 2, 1, 1, 0, 1, 2, 1, 3, 0, 1, 0, 3, 0, 1, 0, 0, 3, 2,
#        3, 0, 1, 0, 0, 1, 2, 1, 0, 3, 0, 2, 2, 2, 3, 0, 0, 0, 1, 0, 0, 3,
#        1, 3, 0, 3, 2, 3, 1, 0, 0, 1, 3, 0, 2, 0, 1, 1, 1, 0, 2, 3, 3, 0,
#        3, 3, 3, 2, 3, 2, 2, 1, 2, 1, 2, 0, 0, 0, 1, 1, 3, 2, 0, 1, 2, 0,
#        0, 1, 3, 2, 0, 0, 2, 1, 3, 2, 1, 1, 1, 1, 2, 2, 3, 0, 1, 0, 0, 0,
#        3, 0, 1, 1, 1, 1, 1, 3, 0, 0, 3, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print(f"By GaussianNB Acc: {acc2}")
# Out:
# By GaussianNB Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.89      0.94      0.92        18
#            2       0.88      0.88      0.88        16
#            3       0.92      0.73      0.81        15
#
#     accuracy                           0.87        63
#    macro avg       0.87      0.87      0.87        63
# weighted avg       0.88      0.87      0.87        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier =KNeighborsClassifier()
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[13  1  0  0]
#  [ 2 16  0  0]
#  [ 6  0  5  5]
#  [ 2  0  0 13]]

# %%
print(f"By KNeighborsclassifier Acc: {acc2}")
# Out:
# By KNeighborsclassifier Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.93      0.70        14
#            1       0.94      0.89      0.91        18
#            2       1.00      0.31      0.48        16
#            3       0.72      0.87      0.79        15
#
#     accuracy                           0.75        63
#    macro avg       0.81      0.75      0.72        63
# weighted avg       0.82      0.75      0.73        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier =DecisionTreeClassifier()
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc7 = accuracy_score(y_test, y_pred)
# Out:
# [[12  2  0  0]
#  [ 1 17  0  0]
#  [ 2  0 12  2]
#  [ 1  1  2 11]]

# %%
print(f"By DecisionTreeclassifier Acc: {acc2}")
# Out:
# By DecisionTreeclassifier Acc: 0.8888888888888888

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        14
#            1       0.85      0.94      0.89        18
#            2       0.86      0.75      0.80        16
#            3       0.85      0.73      0.79        15
#
#     accuracy                           0.83        63
#    macro avg       0.83      0.82      0.82        63
# weighted avg       0.83      0.83      0.82        63

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier ,BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# Assuming you have created classifier instances for each model
svm = SVC()
rfc = RandomForestClassifier()
gbc  = GradientBoostingClassifier()
adb  = AdaBoostClassifier()
bgc  =BaggingClassifier()
lr = LogisticRegression()
gnb = GaussianNB()
knn = KNeighborsClassifier()
dtc = DecisionTreeClassifier()

classifiers = [svm,rfc,gbc,adb,bgc,lr,gnb,knn,dtc]

# Placeholder data for Accuracy, F1_Score, Precision, and Recall
accuracy_data = [0.87, 0.94, 0.86, 0.62, 0.92, 0.87, 0.87, 0.75,0.87]
f1_score_data = [0.87, 0.93, 0.85, 0.57, 0.92, 0.87, 0.87, 0.72,0.87]
precision_data = [0.88, 0.95, 0.87, 0.80, 0.92, 0.87, 0.87, 0.81,0.85]
recall_data = [0.87, 0.94, 0.85, 0.62, 0.92, 0.88, 0.87, 0.75,0.88]

# Create the DataFrame
world_df = {
    'Models': classifiers,
    'Accuracy': accuracy_data,
    'F1_Score': f1_score_data,
    'Precision': precision_data,
    'Recall': recall_data
}

results_world_df = pd.DataFrame(world_df)
sorted_results = results_world_df.sort_values(by=['Accuracy'], ascending=False)

print(sorted_results)
# Out:
#                          Models  Accuracy  F1_Score  Precision  Recall
# 1      RandomForestClassifier()      0.94      0.93       0.95    0.94
# 4           BaggingClassifier()      0.92      0.92       0.92    0.92
# 0                         SVC()      0.87      0.87       0.88    0.87
# 5          LogisticRegression()      0.87      0.87       0.87    0.88
# 6                  GaussianNB()      0.87      0.87       0.87    0.87
# 8      DecisionTreeClassifier()      0.87      0.87       0.85    0.88
# 2  GradientBoostingClassifier()      0.86      0.85       0.87    0.85
# 7        KNeighborsClassifier()      0.75      0.72       0.81    0.75
# 3          AdaBoostClassifier()      0.62      0.57       0.80    0.62

# %%
# dump(model,open('RandomForestClassifier.sav', 'wb'))
